# %%
import torch
import matplotlib.pyplot as plt

seed = 100
path = './attention/record/' + str(seed) + '/info_dict'
info_dict = torch.load(path)
train_loss_list = info_dict['train_loss_list']
validate_loss_list = info_dict['validate_loss_list']
train_acc_list = info_dict['train_acc_list']
validate_acc_list = info_dict['validate_acc_list']
step_finished = info_dict['step']
epoch = len(train_loss_list)

epochs = []
for i in range(epoch):
    epochs.append(i+1)

# %%
num_hiddens = 128
warmup_steps = 4000
factor = 0.1
step_list = []
lrate_list = []

for i in range(step_finished):
    step_list.append(i+1)
    lrate = factor * num_hiddens ** (-0.5) * \
        min((i+1) ** (-0.5), (i+1) * warmup_steps ** (-1.5))
    lrate_list.append(lrate)
    
plt.plot(step_list,lrate_list)
plt.grid()
plt.show()

# %%
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(epochs, train_loss_list, label='Training Loss')
plt.plot(epochs, validate_loss_list, label='Validatation Loss')
plt.title('Training and Validation Loss')
plt.grid()
plt.legend()

# %%
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(epochs, train_acc_list, label='Training Acc')
plt.plot(epochs, validate_acc_list, label='Validation Acc')
plt.title('Training and Validation Accuracy')
plt.grid()
plt.legend()

# %%
print(info_dict['validate_loss_list'])
# Out:
# [0.7051228106463397, 0.5213956431989316, 0.12870494061046175, 0.04936984026873553, 0.030128942750118397, 0.019776432304470626, 0.011846756347351604, 0.00784845763610469, 0.00867581260425073, 0.004488785385533616]

# %%
print(info_dict['validate_acc_list'])
# Out:
# [0.3307753843228254, 0.539328797323914, 0.8909200885272736, 0.9520053709862245, 0.9688986318072794, 0.9788538165401535, 0.9879802040223463, 0.9922775750739433, 0.9930603729084583, 0.9960688771950839]

# %%
print(info_dict['inner_test_acc'])
# Out:
# {'avg_string_acc': 0.9823757832784925, 'avg_template_acc': 0.9840449151084472, 'avg_bleu_score': 0.9959522703317799}

# %%
print(info_dict['extrapolate_test_acc'])
# Out:
# {'avg_string_acc': 0.6936942468134858, 'avg_template_acc': 0.7984687933887441, 'avg_bleu_score': 0.9330933626264419}

# %%
print(info_dict)
# Out:
# {'step': 15190, 'train_loss_list': [1.1057921649399118, 0.6354219833421119, 0.3270216050560092, 0.07571744725782685, 0.03913988860055743, 0.024697824487838235, 0.015203388409359465, 0.009564928719658911, 0.006551437456421401, 0.0046683854319216535], 'train_acc_list': [0.190438026864105, 0.40649992440735694, 0.7149366172394477, 0.9323732904252282, 0.9611945465556425, 0.9742848961213312, 0.9844872581779774, 0.990643119903285, 0.9937221369091879, 0.995582773689504], 'validate_loss_list': [0.7051228106463397, 0.5213956431989316, 0.12870494061046175, 0.04936984026873553, 0.030128942750118397, 0.019776432304470626, 0.011846756347351604, 0.00784845763610469, 0.00867581260425073, 0.004488785385533616], 'validate_acc_list': [0.3307753843228254, 0.539328797323914, 0.8909200885272736, 0.9520053709862245, 0.9688986318072794, 0.9788538165401535, 0.9879802040223463, 0.9922775750739433, 0.9930603729084583, 0.9960688771950839], 'inner_test_acc': {'avg_string_acc': 0.9823757832784925, 'avg_template_acc': 0.9840449151084472, 'avg_bleu_score': 0.9959522703317799}, 'extrapolate_test_acc': {'avg_string_acc': 0.6936942468134858, 'avg_template_acc': 0.7984687933887441, 'avg_bleu_score': 0.9330933626264419}}
